# %%
import pandas as pd
import os

# %%
#Setting the file folder and the file path

folder_path = "../Raw_Files/"
path_races_2018_2023_appended = "races_2018_2023_appended.csv"

# %%
#Reading file and checking the data type

df_races_2018_2023_appended = pd.read_csv(folder_path + path_races_2018_2023_appended)
display(df_races_2018_2023_appended)
print(df_races_2018_2023_appended.dtypes)
# Out:
#                                        Circuit        Date Pos  No  \
# 0     Melbourne Grand Prix Circuit - Melbourne  2018-03-25   1   5
# 1     Melbourne Grand Prix Circuit - Melbourne  2018-03-25   2  44
# 2     Melbourne Grand Prix Circuit - Melbourne  2018-03-25   3   7
# 3     Melbourne Grand Prix Circuit - Melbourne  2018-03-25   4   3
# 4     Melbourne Grand Prix Circuit - Melbourne  2018-03-25   5  14
# ...                                        ...         ...  ..  ..
# 2494           Yas Marina Circuit - Yas Island  2023-11-26  16   2
# 2495           Yas Marina Circuit - Yas Island  2023-11-26  17  24
# 2496           Yas Marina Circuit - Yas Island  2023-11-26  18  55
# 2497           Yas Marina Circuit - Yas Island  2023-11-26  19  77
# 2498           Yas Marina Circuit - Yas Island  2023-11-26  20  20
#
#                     Driver                        Car  Laps Time/Retired  \
# 0     Sebastian Vettel VET                    Ferrari    58  1:29:33.283
# 1       Lewis Hamilton HAM                   Mercedes    58      +5.036s
# 2       Kimi Räikkönen RAI                    Ferrari    58      +6.309s
# 3     Daniel Ricciardo RIC  Red Bull Racing TAG Heuer    58      +7.069s
# 4      Fernando Alonso ALO            McLaren Renault    58     +27.886s
# ...                    ...                        ...   ...          ...
# 2494    Logan Sargeant SAR          Williams Mercedes    58     +87.791s
# 2495       Zhou Guanyu ZHO         Alfa Romeo Ferrari    58     +89.422s
# 2496      Carlos Sainz SAI                    Ferrari    57          DNF
# 2497   Valtteri Bottas BOT         Alfa Romeo Ferrari    57       +1 lap
# 2498   Kevin Magnussen MAG               Haas Ferrari    57       +1 lap
#
#        PTS  Year Driver_Name_Abbreviation
# 0     25.0  2018                      VET
# 1     18.0  2018                      HAM
# 2     15.0  2018                      RAI
# 3     12.0  2018                      RIC
# 4     10.0  2018                      ALO
# ...    ...   ...                      ...
# 2494   0.0  2023                      SAR
# 2495   0.0  2023                      ZHO
# 2496   0.0  2023                      SAI
# 2497   0.0  2023                      BOT
# 2498   0.0  2023                      MAG
#
# [2499 rows x 11 columns]
# Circuit                      object
# Date                         object
# Pos                          object
# No                            int64
# Driver                       object
# Car                          object
# Laps                          int64
# Time/Retired                 object
# PTS                         float64
# Year                          int64
# Driver_Name_Abbreviation     object
# dtype: object

# %%
df_races_2018_2023 = df_races_2018_2023_appended.loc[:, ['Circuit']]

# %%
display(df_races_2018_2023)
# Out:
#                                        Circuit
# 0     Melbourne Grand Prix Circuit - Melbourne
# 1     Melbourne Grand Prix Circuit - Melbourne
# 2     Melbourne Grand Prix Circuit - Melbourne
# 3     Melbourne Grand Prix Circuit - Melbourne
# 4     Melbourne Grand Prix Circuit - Melbourne
# ...                                        ...
# 2494           Yas Marina Circuit - Yas Island
# 2495           Yas Marina Circuit - Yas Island
# 2496           Yas Marina Circuit - Yas Island
# 2497           Yas Marina Circuit - Yas Island
# 2498           Yas Marina Circuit - Yas Island
#
# [2499 rows x 1 columns]

# %%
df_races_2018_2023 = df_races_2018_2023.drop_duplicates(subset=['Circuit'])
display(df_races_2018_2023)
# Out:
#                                                 Circuit
# 0              Melbourne Grand Prix Circuit - Melbourne
# 20               Bahrain International Circuit - Sakhir
# 40            Shanghai International Circuit - Shanghai
# 60                             Baku City Circuit - Baku
# 80           Circuit de Barcelona-Catalunya - Barcelona
# 100                     Circuit de Monaco - Monte Carlo
# 120                Circuit Gilles-Villeneuve - Montréal
# 140                  Circuit Paul Ricard - Le Castellet
# 160                           Red Bull Ring - Spielberg
# 180                   Silverstone Circuit - Silverstone
# 200                         Hockenheimring - Hockenheim
# 220                              Hungaroring - Budapest
# 240    Circuit de Spa-Francorchamps - Spa-Francorchamps
# 260                   Autodromo Nazionale Monza - Monza
# 280               Marina Bay Street Circuit - Singapore
# 300                              Sochi Autodrom - Sochi
# 320         Suzuka International Racing Course - Suzuka
# 340                    Circuit of The Americas - Austin
# 360          Autódromo Hermanos Rodríguez - Mexico City
# 380              Autódromo José Carlos Pace - São Paulo
# 400                     Yas Marina Circuit - Yas Marina
# 820                     Yas Marina Circuit - Yas Island
# 1000                                  Mugello - Mugello
# 1040                          Nürburgring - Nürburgring
# 1060      Autódromo Internacional do Algarve - Portimão
# 1080              Autodromo Enzo e Dino Ferrari - Imola
# 1100                 Intercity Istanbul Park - Istanbul
# 1140  Bahrain International Circuit – Outer Track - ...
# 1420                      Circuit Zandvoort - Zandvoort
# 1560              Lusail International Circuit - Lusail
# 1580                   Jeddah Corniche Circuit - Jeddah
# 1700              Miami International Autodrome - Miami
# 1740                         Circuit de Monaco - Monaco
# 1940             Marina Bay Street Circuit - Marina Bay
# 2459                Las Vegas Strip Circuit - Las Vegas

# %%
#output_directory = 'C:/Users/bruno/Projetos Python/F1_Prediction/Clean_Files/'

# Export DataFrame to CSV file in the specified directory
#df_races_2018_2023.to_csv(output_directory + 'circuits.csv', index=False)
